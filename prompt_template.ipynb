# %%
import yaml
from typing import Any, Dict

def _load_yaml(path: str) -> Dict[str, Any]:
    with open(path, "r", encoding="utf-8") as f:
        obj = yaml.safe_load(f) or {}
    if not isinstance(obj, dict):
        raise ValueError(f"Invalid yaml: {path}")
    return obj

# %%
template_path = "core/prompts/knowledge_extraction/entity_extraction.yaml"

template = _load_yaml(template_path)

# %%
template
# Out:
# {'id': 'entity_extraction',
#  'category': 'knowledge_extraction',
#  'name': 'Entity Extraction',
#  'description': 'Extract entities from narrative text with strict JSON output.\n',
#  'task_variables': [{'name': 'text',
#    'type': 'string',
#    'required': True,
#    'description': 'Input chunk text.'}],
#  'static_variables': [{'name': 'task_name',
#    'type': 'string',
#    'required': True,
#    'description': 'Short name of the extraction task, shown in the prompt header.'},
#   {'name': 'task_goal',
#    'type': 'string',
#    'required': True,
#    'description': 'Precise description of what the entity extraction task should accomplish.'},
#   {'name': 'global_constraints',
#    'type': 'string',
#    'required': True,
#    'description': 'Global rules and constraints that must always be followed during extraction.'},
#   {'name': 'type_definitions',
#    'type': 'string',
#    'required': True,
# ...

# %%
import json

def load_json(path: str) -> Any:
    with open(path, "r", encoding="utf-8") as f:
        return json.load(f) 
    
entity_extraction_task = load_json("core/schema/full_entity_schema.json")

# %%
entity_extraction_task[0]
# Out:
# {'task': 'general_entity_extraction',
#  'task_name': 'Narrative Entity Extraction',
#  'task_goal': 'Extract Characters, Concepts, and Objects that exist in the narrative world and are relevant to the story. Entities must be grounded in the text and usable as structured nodes in a narrative knowledge graph.',
#  'global_constraints': ['Do NOT invent entities that are not explicitly grounded in the text.',
#   'Exclude purely cinematic devices or formatting artifacts.',
#   'Prefer stable, canonical names; avoid duplicate variants unless the text clearly distinguishes them.',
#   'Output JSON only. Do NOT include commentary or extra text.'],
#  'types': [{'type': 'Character',
#    'description': 'A concrete individual entity that participates in the narrative (human or anthropomorphized agent).',
#    'properties': {'name': 'Canonical name or form of address for this character node.',
#     'gender': 'Gender (optional, if explicitly stated).',
# ...

# %%
print(template["template"])
# Out:
# You are performing knowledge graph entity extraction.
# Task:
# {task_name}
#
# Goal:
# {task_goal}
#
# Global constraints:
# {global_constraints}
#
# Types:
# {type_definitions}
#
# Output format:
# Return a JSON array.
# Each element must include exactly:
# {output_fields_block}
#
# Do NOT include any additional fields.
# Do NOT include explanations, commentary, or additional text outside the JSON.
#
# Examples:
# {few_shot_samples}
#
# Input Text:
# {text}
